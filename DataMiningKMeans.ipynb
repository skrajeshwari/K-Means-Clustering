# %%
# Importing the libraries

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt # for data visualization
import seaborn as sns # for statistical data visualization

# %matplotlib inline

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
import warnings

warnings.filterwarnings('ignore')

# %%
# Importing the dataset
df = pd.read_csv(r"C:\Users\User\Desktop\MScBusinessAnalytics and Big Data\Assignments\Data Mining and Machine Learning\q2\countries of the world.csv", encoding= "ISO-8859-1")

# %%
df
# Out:
#              Country                               Region  Population  \
# 0       Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1           Albania   EASTERN EUROPE                          3581655
# 2           Algeria   NORTHERN AFRICA                        32930091
# 3    American Samoa   OCEANIA                                   57794
# 4           Andorra   WESTERN EUROPE                            71201
# ..               ...                                  ...         ...
# 222       West Bank   NEAR EAST                               2460492
# 223  Western Sahara   NORTHERN AFRICA                          273008
# 224           Yemen   NEAR EAST                              21456188
# 225          Zambia   SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe   SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# ...

# %%
df.shape
# Out:
# (227, 20)

# %%
df.head()
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 0          647500                       48,0                         0,00
# 1           28748                      124,6                         1,26
# 2         2381740                       13,8                         0,04
# 3             199                      290,4                        58,29
# 4             468                      152,1                         0,00
#
#   Net migration Infant mortality (per 1000 births)  GDP ($ per capita)  \
# ...

# %%
# Using the elbow method to find the optimal number of clusters

X = df.iloc[:,1:11]
X
# Out:
#                                   Region  Population  Area (sq. mi.)  \
# 0          ASIA (EX. NEAR EAST)             31056997          647500
# 1    EASTERN EUROPE                          3581655           28748
# 2    NORTHERN AFRICA                        32930091         2381740
# 3    OCEANIA                                   57794             199
# 4    WESTERN EUROPE                            71201             468
# ..                                   ...         ...             ...
# 222  NEAR EAST                               2460492            5860
# 223  NORTHERN AFRICA                          273008          266000
# 224  NEAR EAST                              21456188          527970
# 225  SUB-SAHARAN AFRICA                     11502010          752614
# 226  SUB-SAHARAN AFRICA                     12236805          390580
#
#     Pop. Density (per sq. mi.) Coastline (coast/area ratio) Net migration  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 20 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Country                             227 non-null    object
#  1   Region                              227 non-null    object
#  2   Population                          227 non-null    int64
#  3   Area (sq. mi.)                      227 non-null    int64
#  4   Pop. Density (per sq. mi.)          227 non-null    object
#  5   Coastline (coast/area ratio)        227 non-null    object
#  6   Net migration                       224 non-null    object
#  7   Infant mortality (per 1000 births)  224 non-null    object
#  8   GDP ($ per capita)                  226 non-null    float64
#  9   Literacy (%)                        209 non-null    object
#  10  Phones (per 1000)                   223 non-null    object
# ...

# %%
#Checking for missing values in dataset

df.isnull().sum()
# Out:
# Country                                0
# Region                                 0
# Population                             0
# Area (sq. mi.)                         0
# Pop. Density (per sq. mi.)             0
# Coastline (coast/area ratio)           0
# Net migration                          3
# Infant mortality (per 1000 births)     3
# GDP ($ per capita)                     1
# Literacy (%)                          18
# Phones (per 1000)                      4
# Arable (%)                             2
# Crops (%)                              2
# Other (%)                              2
# Climate                               22
# Birthrate                              3
# Deathrate                              4
# Agriculture                           15
# Industry                              16
# Service                               15
# dtype: int64

# %%
X = df.iloc[:,1:4]
X
# Out:
#                                   Region  Population  Area (sq. mi.)
# 0          ASIA (EX. NEAR EAST)             31056997          647500
# 1    EASTERN EUROPE                          3581655           28748
# 2    NORTHERN AFRICA                        32930091         2381740
# 3    OCEANIA                                   57794             199
# 4    WESTERN EUROPE                            71201             468
# ..                                   ...         ...             ...
# 222  NEAR EAST                               2460492            5860
# 223  NORTHERN AFRICA                          273008          266000
# 224  NEAR EAST                              21456188          527970
# 225  SUB-SAHARAN AFRICA                     11502010          752614
# 226  SUB-SAHARAN AFRICA                     12236805          390580
#
# [227 rows x 3 columns]

# %%
from sklearn.cluster import KMeans
wcss = []

X = df.iloc[:,1:11]
X
# Out:
#                                   Region  Population  Area (sq. mi.)  \
# 0          ASIA (EX. NEAR EAST)             31056997          647500
# 1    EASTERN EUROPE                          3581655           28748
# 2    NORTHERN AFRICA                        32930091         2381740
# 3    OCEANIA                                   57794             199
# 4    WESTERN EUROPE                            71201             468
# ..                                   ...         ...             ...
# 222  NEAR EAST                               2460492            5860
# 223  NORTHERN AFRICA                          273008          266000
# 224  NEAR EAST                              21456188          527970
# 225  SUB-SAHARAN AFRICA                     11502010          752614
# 226  SUB-SAHARAN AFRICA                     12236805          390580
#
#     Pop. Density (per sq. mi.) Coastline (coast/area ratio) Net migration  \
# ...

# %%
from sklearn.cluster import KMeans
wcss = []

# %%
df.drop_duplicates(inplace=True)

# %%
X
# Out:
#      Code  Year  \
# 0     AFG  1990
# 1     AFG  1991
# 2     AFG  1992
# 3     AFG  1993
# 4     AFG  1994
# ...   ...   ...
# 6463  ZWE  2013
# 6464  ZWE  2014
# 6465  ZWE  2015
# 6466  ZWE  2016
# 6467  ZWE  2017
#
#       Deaths - Unsafe water source - Sex: Both - Age: All Ages (Number)
# 0                                           7554.049543
# 1                                           7359.676749
# 2                                           7650.437822
# 3                                          10270.731380
# 4                                          11409.177110
# ...                                                 ...
# 6463                                        4254.282075
# 6464                                        4098.769691
# 6465                                        3921.291358
# 6466                                        3802.257512
# 6467                                        3796.070615
#
# [6468 rows x 3 columns]

# %%
# using only Literacy (%) and GDP ($ per capita) variable for easy visualisation

X = df.iloc[:, [8, 9]]

# %%
X
# Out:
#      GDP ($ per capita) Literacy (%)
# 0                 700.0         36,0
# 1                4500.0         86,5
# 2                6000.0         70,0
# 3                8000.0         97,0
# 4               19000.0        100,0
# ..                  ...          ...
# 222               800.0          NaN
# 223                 NaN          NaN
# 224               800.0         50,2
# 225               800.0         80,6
# 226              1900.0         90,7
#
# [227 rows x 2 columns]

# %%
# Using the elbow method to find the optimal number of clusters
from sklearn.cluster import KMeans

# %%
wcss = []

# %%
for i in range(1,11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(X) 
    kmeans.transform(X)
    wcss.append(kmeans.inertia_)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-144-e67eaa9df11a> in <module>
#       1 for i in range(1,11):
#       2     kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
# ----> 3     kmeans.fit(X)
#       4     kmeans.transform(X)
#       5     wcss.append(kmeans.inertia_)
#
# ~\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py in fit(self, X, y, sample_weight)
#     977             Fitted estimator.
#     978         """
# --> 979         X = self._validate_data(X, accept_sparse='csr',
#     980                                 dtype=[np.float64, np.float32],
#     981                                 order='C', copy=self.copy_x,
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     419             out = X
# ...

# %%
   X = df.iloc[:, [8, 9]].values

# %%
 X
# Out:
# array([[700.0, '36,0'],
#        [4500.0, '86,5'],
#        [6000.0, '70,0'],
#        [8000.0, '97,0'],
#        [19000.0, '100,0'],
#        [1900.0, '42,0'],
#        [8600.0, '95,0'],
#        [11000.0, '89,0'],
#        [11200.0, '97,1'],
#        [3500.0, '98,6'],
#        [28000.0, '97,0'],
#        [29000.0, '100,0'],
#        [30000.0, '98,0'],
#        [3400.0, '97,0'],
#        [16700.0, '95,6'],
#        [16900.0, '89,1'],
#        [1900.0, '43,1'],
#        [15700.0, '97,4'],
#        [6100.0, '99,6'],
#        [29100.0, '98,0'],
#        [4900.0, '94,1'],
#        [1100.0, '40,9'],
#        [36000.0, '98,0'],
#        [1300.0, '42,2'],
#        [2400.0, '87,2'],
#        [6100.0, nan],
#        [9000.0, '79,8'],
#        [7600.0, '86,4'],
#        [16000.0, '97,8'],
#        [18600.0, '93,9'],
#        [7600.0, '98,6'],
#        [1100.0, '26,6'],
#        [1800.0, '85,3'],
#        [600.0, '51,6'],
#        [1900.0, '69,4'],
#        [1800.0, '79,0'],
# ...

# %%
 kmeans.fit(X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-79-28568fcd941d> in <module>
# ----> 1 kmeans.fit(X)
#
# ~\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py in fit(self, X, y, sample_weight)
#     977             Fitted estimator.
#     978         """
# --> 979         X = self._validate_data(X, accept_sparse='csr',
#     980                                 dtype=[np.float64, np.float32],
#     981                                 order='C', copy=self.copy_x,
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     419             out = X
#     420         elif isinstance(y, str) and y == 'no_validation':
# --> 421             X = check_array(X, **check_params)
#     422             out = X
#     423         else:
#
# ...
